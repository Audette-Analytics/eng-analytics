# %%
import os
import json
import numpy
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.cm as cm
import numpy as np
import pandas as pd
import calendar
import datetime
from IPython.display import Markdown, display, Javascript, display_html

def df_style(header=20, body=16, max_width=100):
    dfstyle = [dict(selector="th", props=[('font-size', f'{header}px')]),
               dict(selector="td", props=[('font-size', f'{body}px')]),
               dict(selector="td", props=[('text-align', 'center')]),
               dict(selector="th", props=[('text-align', 'center')]),
               dict(selector='th', props=[('max-width',f'{max_width}px;')])]
    return dfstyle

# %%
# ----- INPUTS HERE ----- #
building_name = 'Testing'
f = open(f'./response_1678286136012.json')
customer_name = 'Testing'

# %%
data = json.load(f)
file_name = os.path.splitext(f.name)[0]

# %% [markdown]
# <img src=https://res.cloudinary.com/crunchbase-production/image/upload/c_lpad,f_auto,q_auto:eco,dpr_1/htdkfr3co4n7wyxpslr0 alt="Drawing" style="width: 500px;" align="left"/>

# %%
display(Markdown(f"# Carbon Reduction Plan for {building_name}"))
display(Markdown(f"## Prepared for {customer_name}"))
display(Markdown(f"### {datetime.datetime.now().strftime('%B %Y')}"))
display(Markdown("***"))
# Out:
# # Carbon Reduction Plan for Wildrose Residence
# ## Prepared for Testing
# ### March 2023
# ***

# %% [markdown]
# ### Building Summary

# %%
building_details_data = [
    data['base_building_state']['building_archetype'],
    data['base_building_state']['gross_floor_area'],
    data['base_building_state']['floors_above_grade']
]

# %%
building_details = pd.DataFrame(
    data=building_details_data,
    index=[
        'Building Type',
        'Floor Area (m²)',
        'Number of Floors'
    ],
    columns=['']
)
# building_details
display(building_details.T.style.set_table_styles(df_style(header=16, body=16, max_width=150)))
# Out:
# <style type="text/css">
# #T_99f76 th {
#   font-size: 16px;
# }
# #T_99f76 td {
#   font-size: 16px;
# }
# #T_99f76 td {
#   text-align: center;
# }
# #T_99f76 th {
#   text-align: center;
# }
# #T_99f76 th {
#   max-width: 150px;;
# }
# </style>
# <table id="T_99f76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99f76_level0_col0" class="col_heading level0 col0" >Building Type</th>
#       <th id="T_99f76_level0_col1" class="col_heading level0 col1" >Floor Area (m²)</th>
#       <th id="T_99f76_level0_col2" class="col_heading level0 col2" >Number of Floors</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99f76_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_99f76_row0_col0" class="data row0 col0" >multi_unit_residential</td>
#       <td id="T_99f76_row0_col1" class="data row0 col1" >46.880000</td>
#       <td id="T_99f76_row0_col2" class="data row0 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Carbon Reduction Plan Inputs

# %%
#data from json
crpo_run_options = data['raw_data']['crpo_run_options']

df_options = pd.DataFrame.from_records(crpo_run_options,index=[''])
df_options.columns = df_options.columns.str.replace("_"," ").str.title()

# fka as df1
df_weights = df_options[['Weight Abatement Cost','Weight Emission Saving','Weight Net Present Value','Weight Payback Years']].round(2)

# fka as df2
df_carbon_scenario = df_options.loc[:,['Carbon Scenario','Net Present Value Discount Rate']]
df_carbon_scenario['Carbon Scenario'] = df_carbon_scenario['Carbon Scenario'].str.replace('_'," ").str.title()
df_carbon_scenario.loc["",["2023 Carbon Price per Tonne","2030 Carbon Price per Tonne","2050 Carbon Price per Tonne"]] = [65,170,300]

# fka as df3
elec_gas_rates_data = [
    data['building_analysis']['yearly_summaries'][0]['utility_rates']['electricity'],
    data['building_analysis']['yearly_summaries'][0]['utility_rates']['natural_gas']
]
df_elec_gas_rates = pd.DataFrame(
    data=elec_gas_rates_data,
    index=['Electricity Cost ($/kWh)','Natural Gas Cost ($/kWh)'],
    columns=[""]
).T

### print dataframes side by side
space = "\xa0" * 5

df_weights_s = df_weights.style.set_table_attributes("style='display:inline'")
df_carbon_scenario_s = df_carbon_scenario.style.set_table_attributes("style='display:inline'")
df_elec_gas_rates_s = df_elec_gas_rates.style.set_table_attributes("style='display:inline'")

df_weights_mapper = {k: "{0:.2f}" for k in df_weights.columns}
df_carbon_scenario_mapper = {k: "${0:.0f}" for k in ['2023 Carbon Price per Tonne','2030 Carbon Price per Tonne','2050 Carbon Price per Tonne']}
df_carbon_scenario_mapper['Net Present Value Discount Rate'] = '{:,.0%}'
df_elec_gas_rates_mapper = {k: "{0:.4f}" for k in df_elec_gas_rates.columns}

display_html(df_weights_s.set_table_styles(df_style(header=16, body=16, max_width=75)).format(df_weights_mapper)._repr_html_()
             +space+df_carbon_scenario_s.set_table_styles(df_style(header=16, body=16, max_width=75)).format(df_carbon_scenario_mapper)._repr_html_()
             +space+df_elec_gas_rates_s.set_table_styles(df_style(header=16, body=16, max_width=100)).format(df_elec_gas_rates_mapper)._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# #T_fbfc9 th {
#   font-size: 16px;
# }
# #T_fbfc9 td {
#   font-size: 16px;
# }
# #T_fbfc9 td {
#   text-align: center;
# }
# #T_fbfc9 th {
#   text-align: center;
# }
# #T_fbfc9 th {
#   max-width: 75px;;
# }
# </style>
# <table id="T_fbfc9" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbfc9_level0_col0" class="col_heading level0 col0" >Weight Abatement Cost</th>
#       <th id="T_fbfc9_level0_col1" class="col_heading level0 col1" >Weight Emission Saving</th>
#       <th id="T_fbfc9_level0_col2" class="col_heading level0 col2" >Weight Net Present Value</th>
#       <th id="T_fbfc9_level0_col3" class="col_heading level0 col3" >Weight Payback Years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbfc9_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_fbfc9_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_fbfc9_row0_col1" class="data row0 col1" >0.65</td>
#       <td id="T_fbfc9_row0_col2" class="data row0 col2" >0.35</td>
#       <td id="T_fbfc9_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#   </tbody>
# </table>
#      <style type="text/css">
# #T_69d40 th {
#   font-size: 16px;
# }
# #T_69d40 td {
#   font-size: 16px;
# }
# #T_69d40 td {
#   text-align: center;
# }
# #T_69d40 th {
#   text-align: center;
# }
# #T_69d40 th {
#   max-width: 75px;;
# }
# </style>
# <table id="T_69d40" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69d40_level0_col0" class="col_heading level0 col0" >Carbon Scenario</th>
#       <th id="T_69d40_level0_col1" class="col_heading level0 col1" >Net Present Value Discount Rate</th>
#       <th id="T_69d40_level0_col2" class="col_heading level0 col2" >2023 Carbon Price per Tonne</th>
#       <th id="T_69d40_level0_col3" class="col_heading level0 col3" >2030 Carbon Price per Tonne</th>
#       <th id="T_69d40_level0_col4" class="col_heading level0 col4" >2050 Carbon Price per Tonne</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69d40_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_69d40_row0_col0" class="data row0 col0" >Current Policies</td>
#       <td id="T_69d40_row0_col1" class="data row0 col1" >3%</td>
#       <td id="T_69d40_row0_col2" class="data row0 col2" >$65</td>
#       <td id="T_69d40_row0_col3" class="data row0 col3" >$170</td>
#       <td id="T_69d40_row0_col4" class="data row0 col4" >$300</td>
#     </tr>
#   </tbody>
# </table>
#      <style type="text/css">
# #T_68f4b th {
#   font-size: 16px;
# }
# #T_68f4b td {
#   font-size: 16px;
# }
# #T_68f4b td {
#   text-align: center;
# }
# #T_68f4b th {
#   text-align: center;
# }
# #T_68f4b th {
#   max-width: 100px;;
# }
# </style>
# <table id="T_68f4b" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68f4b_level0_col0" class="col_heading level0 col0" >Electricity Cost ($/kWh)</th>
#       <th id="T_68f4b_level0_col1" class="col_heading level0 col1" >Natural Gas Cost ($/kWh)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68f4b_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_68f4b_row0_col0" class="data row0 col0" >0.0963</td>
#       <td id="T_68f4b_row0_col1" class="data row0 col1" >0.0387</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Carbon Reduction Plan Summary

# %%
# Increamental Cost
total_incremental_cost = sum(crm_year['incremental_cost'] for crm_year in data['building_analysis']['applied_carbon_reduction_measures'])

# Abatement Cost
total_marginal_abatement_cost = sum(crm_year['marginal_abatement_cost'] for crm_year in data['building_analysis']['applied_carbon_reduction_measures'])

# Emission Savings
total_carbon_emission_savings = sum(crm_year['annual_mean_carbon_emission_savings'] for crm_year in data['building_analysis']['applied_carbon_reduction_measures'])

df_metrics = pd.DataFrame(
    data=[total_incremental_cost, total_marginal_abatement_cost, total_carbon_emission_savings],
    index=['Total Incremental Cost','Average Abatement Cost per Tonne of Carbon Saved','Total Tonnes of Carbon Avoided'],
    columns=['']
).T

format_mapping={
    'Total Incremental Cost':'${:,.0f}' , 
    'Average Abatement Cost per Tonne of Carbon Saved':'${:,.2f}',
    'Total Tonnes of Carbon Avoided':'{:,.0f}'
}

# teui & carbon totals

# electricity
start_euie = sum(data['building_analysis']['applied_carbon_reduction_measures'][0]['surrogate_energy_model_output']['energy_use_intensity_electricity'].values())
# gas
start_euig = sum(data['building_analysis']['applied_carbon_reduction_measures'][0]['surrogate_energy_model_output']['energy_use_intensity_natural_gas'].values())
start_total_eui = int(start_euie + start_euig)
# start year
start_year = data['building_analysis']['applied_carbon_reduction_measures'][0]['year_applied']

# electricity
end_euie = sum(data['building_analysis']['applied_carbon_reduction_measures'][-1]['surrogate_energy_model_output']['energy_use_intensity_electricity'].values())
# gas
end_euig = sum(data['building_analysis']['applied_carbon_reduction_measures'][-1]['surrogate_energy_model_output']['energy_use_intensity_natural_gas'].values())
end_total_eui = int(end_euie + end_euig)
# end year
end_year = data['building_analysis']['applied_carbon_reduction_measures'][-1]['year_applied']

# ghgs
start_ghgs = int(data['building_analysis']['yearly_summaries'][0]['annual_carbon_emissions'])
end_ghgs = int(data['building_analysis']['yearly_summaries'][-1]['annual_carbon_emissions'])

# summary
summary_data = [
    [start_ghgs, end_ghgs, f'{int((start_ghgs-end_ghgs)/start_ghgs*100)}%'],
    [start_total_eui, end_total_eui, f'{int((start_total_eui-end_total_eui)/start_total_eui*100)}%']
]

summary_df = pd.DataFrame(
    data=summary_data,
    index=['Carbon Emissions (Tonnes CO₂e)','Energy Use Intensity (kWh/m²)'],
    columns=[f'{start_year}',f'{end_year}','Savings']
).T

#print dataframes side by side
space = "\xa0" * 15
df_metrics_styler = df_metrics.style.set_table_attributes("style='display:inline'")
summary_df_styler = summary_df.style.set_table_attributes("style='display:inline'")

display_html(df_metrics_styler.set_table_styles(df_style(header=16, body=16, max_width=150)).format(format_mapping)._repr_html_()
             +space+summary_df_styler.set_table_styles(df_style(header=16, body=16, max_width=150))._repr_html_()
             , raw=True)
# Out:
# <style type="text/css">
# #T_124a6 th {
#   font-size: 16px;
# }
# #T_124a6 td {
#   font-size: 16px;
# }
# #T_124a6 td {
#   text-align: center;
# }
# #T_124a6 th {
#   text-align: center;
# }
# #T_124a6 th {
#   max-width: 150px;;
# }
# </style>
# <table id="T_124a6" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_124a6_level0_col0" class="col_heading level0 col0" >Total Incremental Cost</th>
#       <th id="T_124a6_level0_col1" class="col_heading level0 col1" >Average Abatement Cost per Tonne of Carbon Saved</th>
#       <th id="T_124a6_level0_col2" class="col_heading level0 col2" >Total Tonnes of Carbon Avoided</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_124a6_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_124a6_row0_col0" class="data row0 col0" >$8,266</td>
#       <td id="T_124a6_row0_col1" class="data row0 col1" >$77,358.70</td>
#       <td id="T_124a6_row0_col2" class="data row0 col2" >822</td>
#     </tr>
#   </tbody>
# </table>
#                <style type="text/css">
# #T_35132 th {
#   font-size: 16px;
# }
# #T_35132 td {
#   font-size: 16px;
# }
# #T_35132 td {
#   text-align: center;
# }
# #T_35132 th {
#   text-align: center;
# }
# #T_35132 th {
#   max-width: 150px;;
# }
# </style>
# <table id="T_35132" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35132_level0_col0" class="col_heading level0 col0" >Carbon Emissions (Tonnes CO₂e)</th>
#       <th id="T_35132_level0_col1" class="col_heading level0 col1" >Energy Use Intensity (kWh/m²)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35132_level0_row0" class="row_heading level0 row0" >2023</th>
#       <td id="T_35132_row0_col0" class="data row0 col0" >901</td>
#       <td id="T_35132_row0_col1" class="data row0 col1" >132</td>
#     </tr>
#     <tr>
#       <th id="T_35132_level0_row1" class="row_heading level0 row1" >2050</th>
#       <td id="T_35132_row1_col0" class="data row1 col0" >81</td>
#       <td id="T_35132_row1_col1" class="data row1 col1" >52</td>
#     </tr>
#     <tr>
#       <th id="T_35132_level0_row2" class="row_heading level0 row2" >Savings</th>
#       <td id="T_35132_row2_col0" class="data row2 col0" >91%</td>
#       <td id="T_35132_row2_col1" class="data row2 col1" >60%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Yearly Carbon Reduction Measures

# %%
yearly_crms = pd.DataFrame.from_records(data['building_analysis']['applied_carbon_reduction_measures'])
cols = [
    'carbon_reduction_measure_type'
    , 'year_applied'
    , 'like_for_like_cost'
    , 'measure_cost'
    , 'incremental_cost'
    , 'simple_payback'
    , 'net_present_value'
    , 'internal_rate_of_return'
    , 'marginal_abatement_cost'
    , 'annual_mean_carbon_emission_savings'
    , 'annual_mean_utility_cost_savings'
]
format_mapping={
    'like_for_like_cost'                    : '${:,.0f}', 
    'measure_cost'                          : '${:,.0f}',
    'incremental_cost'                      : '${:,.0f}',
    'simple_payback'                        :  '{:,.1f}',
    'net_present_value'                     : '${:,.0f}',
    'internal_rate_of_return'               :  '{:,.1%}',
    'marginal_abatement_cost'               : '${:,.0f}',
    'annual_mean_carbon_emission_savings'   :  '{:,.0f}',
    'annual_mean_utility_cost_savings'      : '${:,.0f}'
}
yearly_crms_trim = yearly_crms.loc[:, cols]
yearly_crms_trim.replace(np.nan,0, inplace=True)

for key, value in format_mapping.items():
    yearly_crms_trim[key] = yearly_crms_trim[key].apply(value.format)

# %%
yearly_crms_trim.columns = yearly_crms_trim.columns.str.replace("_"," ")
yearly_crms_trim.columns = map(str.title, yearly_crms_trim.columns)
yearly_crms_trim.set_index('Carbon Reduction Measure Type',inplace=True)

# %%
yearly_crms_trim
# Out:
#                                                     Year Applied  \
# Carbon Reduction Measure Type
# Base building state                                         2023
# Reduce Air Infiltration with Traditional Weathe...          2024
# Install DCV Controls                                        2025
# No Action                                                   2026
# Install Low-E Window Film with Climate Appropia...          2027
# Reduce Air Infiltration with Traditional Weathe...          2028
# No Action                                                   2029
# Install Domestic Hot Water Ambient Air-Source H...          2030
# Install Heat-Only Air Source Heat Pump                      2031
# Install LED Lighting                                        2032
# No Action                                                   2033
# No Action                                                   2034
# Replace Chiller with Oil-Free, Magnetic-Bearing...          2035
# No Action                                                   2036
# No Action                                                   2037
# No Action                                                   2038
# No Action                                                   2039
# No Action                                                   2040
# No Action                                                   2041
# No Action                                                   2042
# No Action                                                   2043
# No Action                                                   2044
# No Action                                                   2045
# No Action                                                   2046
# No Action                                                   2047
# No Action                                                   2048
# No Action                                                   2049
# No Action                                                   2050
#
#                                                    Like For Like Cost  \
# Carbon Reduction Measure Type
# Base building state                                                $0
# Reduce Air Infiltration with Traditional Weathe...                 $0
# Install DCV Controls                                               $0
# No Action                                                          $0
# Install Low-E Window Film with Climate Appropia...                 $0
# Reduce Air Infiltration with Traditional Weathe...                 $0
# No Action                                                          $0
# Install Domestic Hot Water Ambient Air-Source H...                $56
# Install Heat-Only Air Source Heat Pump                             $0
# Install LED Lighting                                               $0
# No Action                                                          $0
# No Action                                                          $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...             $1,339
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
# No Action                                                          $0
#
#                                                    Measure Cost  \
# Carbon Reduction Measure Type
# Base building state                                          $0
# Reduce Air Infiltration with Traditional Weathe...         $141
# Install DCV Controls                                     $1,050
# No Action                                                    $0
# Install Low-E Window Film with Climate Appropia...       $2,206
# Reduce Air Infiltration with Traditional Weathe...         $141
# No Action                                                    $0
# Install Domestic Hot Water Ambient Air-Source H...         $201
# Install Heat-Only Air Source Heat Pump                   $3,600
# Install LED Lighting                                       $703
# No Action                                                    $0
# No Action                                                    $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...       $1,620
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
# No Action                                                    $0
#
#                                                    Incremental Cost  \
# Carbon Reduction Measure Type
# Base building state                                              $0
# Reduce Air Infiltration with Traditional Weathe...             $141
# Install DCV Controls                                         $1,050
# No Action                                                        $0
# Install Low-E Window Film with Climate Appropia...           $2,206
# Reduce Air Infiltration with Traditional Weathe...             $141
# No Action                                                        $0
# Install Domestic Hot Water Ambient Air-Source H...             $145
# Install Heat-Only Air Source Heat Pump                       $3,600
# Install LED Lighting                                           $703
# No Action                                                        $0
# No Action                                                        $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...             $281
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
# No Action                                                        $0
#
#                                                    Simple Payback  \
# Carbon Reduction Measure Type
# Base building state                                           0.0
# Reduce Air Infiltration with Traditional Weathe...          140.6
# Install DCV Controls                                         73.0
# No Action                                                     0.0
# Install Low-E Window Film with Climate Appropia...        1,064.2
# Reduce Air Infiltration with Traditional Weathe...          140.6
# No Action                                                     0.0
# Install Domestic Hot Water Ambient Air-Source H...            1.3
# Install Heat-Only Air Source Heat Pump                       40.0
# Install LED Lighting                                         67.9
# No Action                                                     0.0
# No Action                                                     0.0
# Replace Chiller with Oil-Free, Magnetic-Bearing...          197.5
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
# No Action                                                     0.0
#
#                                                    Net Present Value  \
# Carbon Reduction Measure Type
# Base building state                                               $0
# Reduce Air Infiltration with Traditional Weathe...             $-138
# Install DCV Controls                                           $-915
# No Action                                                         $0
# Install Low-E Window Film with Climate Appropia...           $-2,174
# Reduce Air Infiltration with Traditional Weathe...             $-160
# No Action                                                         $0
# Install Domestic Hot Water Ambient Air-Source H...            $1,242
# Install Heat-Only Air Source Heat Pump                       $-2,251
# Install LED Lighting                                           $-605
# No Action                                                         $0
# No Action                                                         $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...             $-263
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
# No Action                                                         $0
#
#                                                    Internal Rate Of Return  \
# Carbon Reduction Measure Type
# Base building state                                                   0.0%
# Reduce Air Infiltration with Traditional Weathe...                  -37.8%
# Install DCV Controls                                                -24.7%
# No Action                                                             0.0%
# Install Low-E Window Film with Climate Appropia...                  -23.5%
# Reduce Air Infiltration with Traditional Weathe...                    0.0%
# No Action                                                             0.0%
# Install Domestic Hot Water Ambient Air-Source H...                  166.4%
# Install Heat-Only Air Source Heat Pump                               -6.0%
# Install LED Lighting                                                -24.9%
# No Action                                                             0.0%
# No Action                                                             0.0%
# Replace Chiller with Oil-Free, Magnetic-Bearing...                  -22.4%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
# No Action                                                             0.0%
#
#                                                    Marginal Abatement Cost  \
# Carbon Reduction Measure Type
# Base building state                                                     $0
# Reduce Air Infiltration with Traditional Weathe...                  $3,122
# Install DCV Controls                                                $1,371
# No Action                                                               $0
# Install Low-E Window Film with Climate Appropia...                 $12,742
# Reduce Air Infiltration with Traditional Weathe...                  $9,901
# No Action                                                               $0
# Install Domestic Hot Water Ambient Air-Source H...                   $-187
# Install Heat-Only Air Source Heat Pump                                $342
# Install LED Lighting                                               $15,430
# No Action                                                               $0
# No Action                                                               $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...                 $34,638
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
# No Action                                                               $0
#
#                                                    Annual Mean Carbon Emission Savings  \
# Carbon Reduction Measure Type
# Base building state                                                                  0
# Reduce Air Infiltration with Traditional Weathe...                                   4
# Install DCV Controls                                                                61
# No Action                                                                            0
# Install Low-E Window Film with Climate Appropia...                                   8
# Reduce Air Infiltration with Traditional Weathe...                                   1
# No Action                                                                            0
# Install Domestic Hot Water Ambient Air-Source H...                                 415
# Install Heat-Only Air Source Heat Pump                                             329
# Install LED Lighting                                                                 4
# No Action                                                                            0
# No Action                                                                            0
# Replace Chiller with Oil-Free, Magnetic-Bearing...                                   0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
# No Action                                                                            0
#
#                                                    Annual Mean Utility Cost Savings
# Carbon Reduction Measure Type
# Base building state                                                              $0
# Reduce Air Infiltration with Traditional Weathe...                               $0
# Install DCV Controls                                                            $14
# No Action                                                                        $0
# Install Low-E Window Film with Climate Appropia...                               $2
# Reduce Air Infiltration with Traditional Weathe...                              $-2
# No Action                                                                        $0
# Install Domestic Hot Water Ambient Air-Source H...                             $109
# Install Heat-Only Air Source Heat Pump                                          $90
# Install LED Lighting                                                            $10
# No Action                                                                        $0
# No Action                                                                        $0
# Replace Chiller with Oil-Free, Magnetic-Bearing...                               $1
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
# No Action                                                                        $0
